# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextIteratorStreamer
import torch

MODEL_ID = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(
    MODEL_ID,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float32,
    device_map="cpu",
    trust_remote_code=True
).eval()

# %%
prompt = "Làm sao để cải thiện chất lượng câu trả lời cho LLM?"

inputs = tokenizer(prompt, return_tensors="pt")

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=128,
        temperature=0.3,
        top_p=0.9
    )

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Làm sao để cải thiện chất lượng câu trả lời cho LLM? - Quyền lợi của người dùng
# Home/Quản lý dữ liệu/Làm sao để cải thiện chất lượng câu trả lời cho LLM?
# Câu hỏi: Tôi muốn tìm hiểu về cách làm thế nào để cải thiện chất lượng câu trả lời cho các hệ thống ngôn ngữ lớn (LLM). Bạn có thể cung cấp một số gợi ý hay không?
# Để cải thiện chất lượng câu trả lời cho các hệ thống ngôn ngữ lớn (LLM), bạn cần thực hiện một số bước sau:
# 1. Đọc và hiểu rõ về cơ chế hoạt động của LLM: LLM là một loại
